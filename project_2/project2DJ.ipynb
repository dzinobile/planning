# %%
import numpy as np
import cv2
import heapq

# %%
h = 50
w = 180
buffer = 2

map = np.zeros((h, w, 3), dtype=np.uint8)
map_limits = map.copy()
map_limits = cv2.cvtColor(map_limits, cv2.COLOR_BGR2GRAY)
map_limits = cv2.rectangle(map_limits, (0,0), (w,h), (255), buffer)
locations = np.where(map_limits == (255))
boundary_xy = set(zip(locations[1], locations[0]))





def add_boundary(inpt_x,inpt_y):
    boundary_xy.add((inpt_x,inpt_y))
    for x in range(inpt_x-buffer, inpt_x+(buffer+1)):
        for y in range(inpt_y-buffer, inpt_y+(buffer+1)):
            boundary_xy.add((x,y))


for y in range(17,35):
    # E
    for x in range(20,40):
        if 16 < y <= 20:
            if 21 < x <= 39:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 20 < y <= 23:
            if 21 < x <= 25:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 23 < y <=27:
            if 21 < x <= 39:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 27 < y <= 30:
            if 21 < x <= 25:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 30 < y <= 34:
            if 21 < x <= 39:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
    
    #N
    for x in range(40,60):
        if 41 < x <= 45:
            map[y,x] = (255,0,0)
            add_boundary(x,y)
        if 55 < x <= 59:
            map[y,x] = (255,0,0)
            add_boundary(x,y)
        if 45 < x <= 55:
            if (1.2*x)-38 < y <= (1.2*x)-32:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
    
    #P
    for x in range(60, 80):
        if 61 < x <=67:
            map[y,x] = (255,0,0)
            add_boundary(x,y)
        if 67 < x <= 79:
            if (((x-67)**2)/(12**2))+(((y-22)**2)/(6**2)) <= 1:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
    
    #M
    for x in range(80,100):
        if 81 < x <=85:
            map[y,x] = (255,0,0)
            add_boundary(x,y)
        if 85 < x <= 90:
            if ((9/5)*x)-137 < y <= ((9/5)*x)-129:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 90 < x <= 95:
            if ((-9/5)*x)+187 < y <= ((-9/5)*x)+195:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 95 < x <= 99:
            map[y,x] = (255,0,0)
            add_boundary(x,y)
    
    #6
    for x in range(100,120):

        if ((x-110)**2)+(y-28.5)**2 <= 5.5**2:
            map[y,x] = (255,0,0)
            map[y,x+20] = (255,0,0)
            add_boundary(x,y)
            add_boundary(x+20,y)
        if ((x-110.85)**2)+(y-18)**2 <= 2**2:
            map[y,x] = (255,0,0)
            map[y,x+20] = (255,0,0)
            add_boundary(x,y)
            add_boundary(x+20,y)
        if x-92.85 < y <=28.5:
            if 12.85**2 < (((x-121.35)**2)+((y-28.5)**2)) <= 16.85**2:
                map[y,x] = (255,0,0)
                map[y,x+20] = (255,0,0)
                add_boundary(x,y)
                add_boundary(x+20,y)

    #1
    for x in range(140,160):
        if 16 < y <= 20.62:
            if 144 < x <= 152:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 20.62 < y <= 30:
            if 148 < x <= 152:
                map[y,x] = (255,0,0)
                add_boundary(x,y)
        if 30 < y <= 34:
            if 144 < x < 156:
                map[y,x] = (255,0,0)
                add_boundary(x,y)

# %%
# test = []
# heapq.heappush(test, (1.5, 5, "test2"))
# heapq.heappush(test, (3, 1, "test3"))
# heapq.heappush(test, (1, 2, "test1"))
# heapq.heappush(test, (100, 5, "test4"))
# heapq.heappush(test, (50, 3, "test5"))
# new_node = (3, 1, "test3")
# test.remove(new_node)

# print(test)
# Out:
# [(1, 2, 'test1'), (1.5, 5, 'test2'), (100, 5, 'test4'), (50, 3, 'test5')]

# %%
start = (5, h-5)
end = (w-5, 5)
open_list = []
closed_list = [(0, 0, start)]

def move(node,direction):
    parent_cost, parent = node[0], node[2]
    if direction == "up":
        child_cost, child = parent_cost+1, (parent[0],parent[1]-1)
    elif direction == "down":
        child_cost, child = parent_cost+1, (parent[0], parent[1]+1)
    elif direction == "left":
        child_cost, child = parent_cost+1, (parent[0]-1,parent[1])
    elif direction == "right":
        child_cost, child = parent_cost+1, (parent[0]+1,parent[1])
    elif direction == "up_right":
        child_cost, child = parent_cost+1.4, (parent[0]+1,parent[1]-1)
    elif direction == "down_right":
        child_cost, child = parent_cost+1.4, (parent[0]+1,parent[1]+1)
    elif direction == "down_left":
        child_cost, child = parent_cost+1.4, (parent[0]-1,parent[1]+1)
    elif direction == "up_left":
        child_cost, child = parent_cost+1.4, (parent[0]-1,parent[1]-1)
    
    if child not in boundary_xy:
        new_node = (child_cost,parent,child)
        heapq.heappush(open_list,new_node)
        #print(open_list)
        for item in open_list:
            if item[2] == child:
                if item[0] > child_cost:
                    open_list.remove(item)
                else:
                    open_list.remove(new_node)

while end not in boundary_xy:
    parent_node = closed_list[-1]
    for direction in ["up","up_right","right","down_right","down","down_left","left","up_left"]:
        move(parent_node,direction)
        print(open_list)
    child_node = heapq.heappop(open_list)
    heapq.heappush(closed_list,child_node)
    boundary_xy.add(child_node[2])

# %%
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 6
#       4     move(parent_node,direction)
#       5     print(open_list)
# ----> 6 child_node = heapq.heappop(open_list)
#       7 heapq.heappush(closed_list,child_node)
#       8 boundary_xy.add(child_node[2])
#
# IndexError: index out of range

# %%
# def up(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0],parent_xy[1]-1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1,index,child_xy))

# def right(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]+1, parent_xy[1])
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1,index, child_xy))

# def down(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0], parent_xy[1]+1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1,index, child_xy))

# def left(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]-1, parent_xy[1])
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1,index, child_xy))

# def up_left(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]-1, parent_xy[1]-1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1.4, index, child_xy))

# def up_right(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]+1, parent_xy[1]-1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1.4, index, child_xy))

# def down_right(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]+1, parent_xy[1]+1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1.4, index, child_xy))

# def down_left(index):
#     parent_xy = cost_parent_child[index][2]
#     parent_cost = cost_parent_child[index][0]
#     child_xy = (parent_xy[0]-1, parent_xy[1]+1)
#     if child_xy not in boundary_xy:
#         cost_parent_child.append((parent_cost+1.4, index, child_xy))

# %%
i = 0
while end not in boundary_xy:
    for item in [up, up_right, right, down_right, down, down_left, left, up_left]:
        item(i)
    
    i += 1

path = [parent_child[-1]]
while path[-1][0] > 0:
    parent_idx = path[-1][0]
    path.append(parent_child[parent_idx])

path.reverse()

# %%
rainbow = [(0,0,255)]


for i in range(0,len(parent_child)):
    ratio = i / (len(parent_child))

    if ratio < 1/3:
        B= 255
        G = int(255*(ratio*3))
        R = 0
    elif ratio < 2/3:
        B = int(255*(2-3*ratio))
        G = 255
        R = int(255*(3*ratio-1))
    else:
        B = 0
        G = int(255*(3-3*ratio))
        R = 255
    rainbow.append((B,G,R))

# %%
frames = []
board_animation = map.copy()
r_i = -1


for item in parent_child:
    b,g,r = rainbow[r_i]
    rc = (item[1][1], item[1][0])
    board_animation[rc] = b,g,r
    frame = board_animation.copy()
    frame = cv2.resize(frame, (0,0), fx=3, fy=3)
    cv2.imshow('animation', frame)
    r_i -=1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

for item in path:   

    rc = (item[1][1], item[1][0])
    board_animation[rc] = 255,255,255
    frame = board_animation.copy()
    frame = cv2.resize(frame, (0,0), fx=3, fy=3)
    cv2.imshow('animation', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
parent_child_dj = []
open_list = []
closed_list = []
heapq.heappush(open_list, (0,0,(start)))
heapq.heappush(closed_list, heapq.heappop(open_list))

def move_up_dj(index):
# Out:
# []
# [(0, 0, (5, 45))]

# %%
test = []
heapq.heappush(test, (1.5, 5, "test2"))
heapq.heappush(test, (3, 1, "test3"))
heapq.heappush(test, (1, 2, "test1"))
while test:
    print(heapq.heappop(test))
# Out:
# (1, 2, 'test1')
# (1.5, 5, 'test2')
# (3, 1, 'test3')
